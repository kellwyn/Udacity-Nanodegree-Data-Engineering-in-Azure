# %% [markdown]
# DIMTIME Dimension Table

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import desc
from pyspark.sql.functions import asc
from pyspark.sql.functions import sum as Fsum
from pyspark.sql import functions as f

import datetime

import numpy as np
import pandas as pd
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
minstartdate = spark.sql('''SELECT MIN(started_at) FROM trips''')
maxstartdate = spark.sql('''SELECT DATEADD(year, 5, MAX(started_at)) FROM trips''')

display(minstartdate)
display(maxstartdate)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min(started_at)</th></tr></thead><tbody><tr><td>2021-02-01 01:07:04</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestampadd(year, 5, max(started_at))</th></tr></thead><tbody><tr><td>2027-01-31T23:58:37.000+0000</td></tr></tbody></table></div>

# %% [markdown]
# Create dimtime dataframe

# %%
times = pd.date_range(start='2021-02-01 01:07:04', end='2027-02-01 01:07:04', freq = 'D')
dimtime = pd.DataFrame(times)
headers = ["time_id"]
dimtime.columns = headers
dimtime['adate'] = pd.DatetimeIndex(dimtime['time_id']).date
dimtime['ayear'] = pd.DatetimeIndex(dimtime['time_id']).year
dimtime['amonth'] = pd.DatetimeIndex(dimtime['time_id']).month
dimtime['aquarter'] = pd.DatetimeIndex(dimtime['time_id']).quarter
dimtime['adayofweek'] = pd.DatetimeIndex(dimtime['time_id']).dayofweek
dimtime['adayofmonth'] = pd.DatetimeIndex(dimtime['time_id']).day
dimtime = dimtime.drop(columns = ['time_id'])
dimtime.insert(0, 'time_id',range(1, 1+len(dimtime)))
dimtime.head()
dimtime=spark.createDataFrame(dimtime)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time_id</th>
#       <th>adate</th>
#       <th>ayear</th>
#       <th>amonth</th>
#       <th>aquarter</th>
#       <th>adayofweek</th>
#       <th>adayofmonth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2021-02-01</td>
#       <td>2021</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>2021-02-02</td>
#       <td>2021</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>2021-02-03</td>
#       <td>2021</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>2021-02-04</td>
#       <td>2021</td>
#       <td>2</td>
#       <td>1</td>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>2021-02-05</td>
#       <td>2021</td>
#       <td>2</td>
#       <td>1</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Create dimtime table using dimtime dataframe in the databricks delta storage

# %%
dimtime.write.format("delta").mode("overwrite").saveAsTable("dimtime")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from dimtime limit 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>time_id</th><th>adate</th><th>ayear</th><th>amonth</th><th>aquarter</th><th>adayofweek</th><th>adayofmonth</th></tr></thead><tbody><tr><td>1</td><td>2021-02-01</td><td>2021</td><td>2</td><td>1</td><td>0</td><td>1</td></tr><tr><td>2</td><td>2021-02-02</td><td>2021</td><td>2</td><td>1</td><td>1</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# DIMSTATION Dimension Table

# %%
dimstation = spark.sql('''
SELECT station_id, name as stationname, latitude, longitude from stations
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dimstation.write.format("delta").mode("overwrite").saveAsTable("dimstation")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from dimstation limit 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>station_id</th><th>stationname</th><th>latitude</th><th>longitude</th></tr></thead><tbody><tr><td>525</td><td>Glenwood Ave & Touhy Ave</td><td>42.012701</td><td>-87.66605799999999</td></tr><tr><td>KA1503000012</td><td>Clark St & Lake St</td><td>41.88579466666667</td><td>-87.63110066666668</td></tr></tbody></table></div>

# %% [markdown]
# DIMRIDER Dimension Table

# %%
dimrider = spark.sql('''
SELECT rider_id, firstname, lastname, address, birthday, is_member as ismember from riders
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dimrider.write.format("delta").mode("overwrite").saveAsTable("dimrider")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from dimrider limit 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rider_id</th><th>firstname</th><th>lastname</th><th>address</th><th>birthday</th><th>ismember</th></tr></thead><tbody><tr><td>1000</td><td>Diana</td><td>Clark</td><td>1200 Alyssa Squares</td><td>1989-02-13</td><td>True</td></tr><tr><td>1001</td><td>Jennifer</td><td>Smith</td><td>397 Diana Ferry</td><td>1976-08-10</td><td>True</td></tr></tbody></table></div>

# %% [markdown]
# FACTPAYMENT Fact Table

# %%
factpayment = spark.sql('''
SELECT payment_id, dates, amount, rider_id from payments
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
factpayment.write.format("delta").mode("overwrite").saveAsTable("factpayment")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from factpayment limit 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_id</th><th>dates</th><th>amount</th><th>rider_id</th></tr></thead><tbody><tr><td>1</td><td>2019-05-01</td><td>9.0</td><td>1000</td></tr><tr><td>2</td><td>2019-06-01</td><td>9.0</td><td>1000</td></tr></tbody></table></div>

# %% [markdown]
# FACTTRIP Fact Table

# %%
facttrip = spark.sql('''
SELECT trips.trip_id, trips.rideable_type, trips.started_at as tripstarttime, trips.ended_at as tripendtime, trips.start_station_id, trips.end_station_id,
DATEDIFF(hour, trips.started_at, trips.ended_at) as duration,
DATEDIFF(year, riders.birthday, trips.started_at) as rider_age,
trips.rider_id
from trips join riders ON riders.rider_id = trips.rider_id 
join dimtime as dt1 ON dt1.adate = LEFT(trips.started_at,10)
join dimtime as dt2 ON dt2.adate = LEFT(trips.ended_at,10)
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
facttrip.write.format("delta").mode("overwrite").saveAsTable("facttrip")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from facttrip limit 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>trip_id</th><th>rideable_type</th><th>tripstarttime</th><th>tripendtime</th><th>start_station_id</th><th>end_station_id</th><th>duration</th><th>rider_age</th><th>rider_id</th></tr></thead><tbody><tr><td>222BB8E5059252D7</td><td>classic_bike</td><td>2021-06-13 09:48:47</td><td>2021-06-13 10:07:23</td><td>KA1503000064</td><td>13021</td><td>0</td><td>30</td><td>34062</td></tr><tr><td>1826E16CB5486018</td><td>classic_bike</td><td>2021-06-21 22:59:13</td><td>2021-06-21 23:04:29</td><td>TA1306000010</td><td>13021</td><td>0</td><td>26</td><td>5342</td></tr></tbody></table></div>
